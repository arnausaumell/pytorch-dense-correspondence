# %%
import os, sys
sys.path.append(os.getcwd() + "/../../modules")
sys.path.append(os.getcwd() + "/../../external")
sys.path.append(os.getcwd() + "/../..")
sys.path.append(os.getcwd() + "/../dataset")

import dense_correspondence_manipulation.utils.utils as utils
utils.add_dense_correspondence_to_python_path()
from dense_correspondence.training.training import *
import sys
import logging
import time

# utils.set_default_cuda_visible_devices()
utils.set_cuda_visible_devices([0, 2]) # use this to manually set CUDA_VISIBLE_DEVICES

from dense_correspondence.training.training import DenseCorrespondenceTraining
from dense_correspondence.dataset.spartan_dataset_masked import SpartanDataset
from dense_correspondence.evaluation.evaluation import DenseCorrespondenceEvaluation
logging.basicConfig(level=logging.INFO)
# Out:
# setting CUDA_VISIBLE_DEVICES =  0,2,

# %% [markdown]
# ## Load the configuration for training

# %%
dc_source_dir = utils.getDenseCorrespondenceSourceDir()

dataset_name = 'shirt_hanging'
config_filename = os.path.join(dc_source_dir, 'config/dense_correspondence/dataset/composite/%s.yaml' % dataset_name)
config = utils.getDictFromYamlFilename(config_filename)

train_config_file = os.path.join(dc_source_dir, 'config/dense_correspondence/training/training.yaml')
train_config = utils.getDictFromYamlFilename(train_config_file)

dataset = SpartanDataset(config=config)

logging_dir = os.path.join(dc_source_dir, "pdc/trained_models/tutorials")

# fixed params
loss_type = 'distributional'
normalize = True
lr = 1.0e-4
sigma = 1
net_type = 'resnet34'
symmetry = True
height, width = dataset.get_height_and_width()

# tunable params
num_iterations = 10000
d = 16

name = "%s_d%d_%s_%s_big" % (dataset_name, d, loss_type, 'sym' if symmetry else 'non_sym')
print("\nModel name:", name)

train_config["training"]["logging_dir_name"] = name
train_config["training"]["logging_dir"] = logging_dir
train_config["training"]["num_iterations"] = num_iterations
train_config["training"]["learning_rate"] = lr
train_config["dense_correspondence_network"]["descriptor_dimension"] = d
train_config["dense_correspondence_network"]["normalize"] = normalize
train_config["dense_correspondence_network"]["loss_type"] = loss_type
train_config["dense_correspondence_network"]["sigma"] = sigma
train_config["dense_correspondence_network"]["net_type"] = net_type
train_config["dense_correspondence_network"]["image_width"] = width
train_config["dense_correspondence_network"]["image_height"] = height
train_config["dense_correspondence_network"]["symmetry"] = symmetry

TRAIN = True
EVALUATE = True
# Out:
# INFO:root:Loading knots info for scene shirt_hanging
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     1500
#
# Model name: shirt_hanging_d16_distributional_sym_big

# %% [markdown]
# ## TRAIN

# %%
if TRAIN:
    start = time.time()
    print("training descriptor of dimension %d" %(d))
    train = DenseCorrespondenceTraining(dataset=dataset, config=train_config)
    train.run()
    print("finished training descriptor of dimension %d" %(d))
    print("training took %d seconds" %(time.time() - start))
# Out:
# INFO:root:enabling domain randomization
# INFO:root:setting up tensorboard_logger
# INFO:root:tensorboard logger started
# training descriptor of dimension 16
# using SINGLE_OBJECT_WITHIN_SCENE
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Training on iteration 10 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 20 of 10000
# INFO:root:single iteration took 0.987 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 30 of 10000
# INFO:root:single iteration took 0.984 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 40 of 10000
# INFO:root:single iteration took 0.985 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 50 of 10000
# INFO:root:single iteration took 0.994 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 60 of 10000
# INFO:root:single iteration took 0.988 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 70 of 10000
# INFO:root:single iteration took 0.982 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 80 of 10000
# INFO:root:single iteration took 1.001 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 90 of 10000
# INFO:root:single iteration took 0.975 seconds
# INFO:root:Training is 0 percent complete
#
# INFO:root:Training on iteration 100 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 110 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 120 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 130 of 10000
# INFO:root:single iteration took 1.008 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 140 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 150 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 160 of 10000
# INFO:root:single iteration took 0.995 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 170 of 10000
# INFO:root:single iteration took 0.986 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 180 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 190 of 10000
# INFO:root:single iteration took 1.028 seconds
# INFO:root:Training is 1 percent complete
#
# INFO:root:Training on iteration 200 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 210 of 10000
# INFO:root:single iteration took 1.181 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 220 of 10000
# INFO:root:single iteration took 1.042 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 230 of 10000
# INFO:root:single iteration took 1.114 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 240 of 10000
# INFO:root:single iteration took 1.107 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 250 of 10000
# INFO:root:single iteration took 1.087 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 260 of 10000
# INFO:root:single iteration took 1.172 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 270 of 10000
# INFO:root:single iteration took 1.104 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 280 of 10000
# INFO:root:single iteration took 1.130 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 290 of 10000
# INFO:root:single iteration took 1.071 seconds
# INFO:root:Training is 2 percent complete
#
# INFO:root:Training on iteration 300 of 10000
# INFO:root:single iteration took 1.075 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 310 of 10000
# INFO:root:single iteration took 1.105 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 320 of 10000
# INFO:root:single iteration took 1.072 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 330 of 10000
# INFO:root:single iteration took 1.042 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 340 of 10000
# INFO:root:single iteration took 1.074 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 350 of 10000
# INFO:root:single iteration took 1.108 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 360 of 10000
# INFO:root:single iteration took 1.163 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 370 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 380 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 390 of 10000
# INFO:root:single iteration took 1.026 seconds
# INFO:root:Training is 3 percent complete
#
# INFO:root:Training on iteration 400 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 410 of 10000
# INFO:root:single iteration took 1.004 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 420 of 10000
# INFO:root:single iteration took 1.024 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 430 of 10000
# INFO:root:single iteration took 0.990 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 440 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 450 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 460 of 10000
# INFO:root:single iteration took 0.990 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 470 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 480 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 490 of 10000
# INFO:root:single iteration took 0.984 seconds
# INFO:root:Training is 4 percent complete
#
# INFO:root:Training on iteration 500 of 10000
# INFO:root:single iteration took 0.995 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 510 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 520 of 10000
# INFO:root:single iteration took 0.983 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 530 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 540 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 550 of 10000
# INFO:root:single iteration took 1.001 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 560 of 10000
# INFO:root:single iteration took 0.990 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 570 of 10000
# INFO:root:single iteration took 1.001 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 580 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 590 of 10000
# INFO:root:single iteration took 1.022 seconds
# INFO:root:Training is 5 percent complete
#
# INFO:root:Training on iteration 600 of 10000
# INFO:root:single iteration took 1.020 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 610 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 620 of 10000
# INFO:root:single iteration took 1.018 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 630 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 640 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 650 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 660 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 670 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 680 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 690 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 6 percent complete
#
# INFO:root:Training on iteration 700 of 10000
# INFO:root:single iteration took 1.026 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 710 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 720 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 730 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 740 of 10000
# INFO:root:single iteration took 0.995 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 750 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 760 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 770 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 780 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 790 of 10000
# INFO:root:single iteration took 1.023 seconds
# INFO:root:Training is 7 percent complete
#
# INFO:root:Training on iteration 800 of 10000
# INFO:root:single iteration took 1.020 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 810 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 820 of 10000
# INFO:root:single iteration took 1.025 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 830 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 840 of 10000
# INFO:root:single iteration took 0.974 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 850 of 10000
# INFO:root:single iteration took 1.022 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 860 of 10000
# INFO:root:single iteration took 0.975 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 870 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 880 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 890 of 10000
# INFO:root:single iteration took 1.139 seconds
# INFO:root:Training is 8 percent complete
#
# INFO:root:Training on iteration 900 of 10000
# INFO:root:single iteration took 1.025 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 910 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 920 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 930 of 10000
# INFO:root:single iteration took 0.996 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 940 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 950 of 10000
# INFO:root:single iteration took 0.993 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 960 of 10000
# INFO:root:single iteration took 1.023 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 970 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 980 of 10000
# INFO:root:single iteration took 1.031 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 990 of 10000
# INFO:root:single iteration took 1.031 seconds
# INFO:root:Training is 9 percent complete
#
# INFO:root:Training on iteration 1000 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 10 percent complete
#
# INFO:root:Training on iteration 1050 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 10 percent complete
#
# INFO:root:Training on iteration 1060 of 10000
# INFO:root:single iteration took 1.095 seconds
# INFO:root:Training is 10 percent complete
#
# INFO:root:Training on iteration 1070 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 10 percent complete
#
# INFO:root:Training on iteration 1080 of 10000
# INFO:root:single iteration took 1.005 seconds
# INFO:root:Training is 10 percent complete
#
# INFO:root:Training on iteration 1090 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 10 percent complete
#
# INFO:root:Training on iteration 1100 of 10000
# INFO:root:single iteration took 1.041 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1110 of 10000
# INFO:root:single iteration took 1.025 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1120 of 10000
# INFO:root:single iteration took 1.007 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1130 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1140 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1150 of 10000
# INFO:root:single iteration took 1.007 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1160 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1170 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1180 of 10000
# INFO:root:single iteration took 1.073 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1190 of 10000
# INFO:root:single iteration took 1.023 seconds
# INFO:root:Training is 11 percent complete
#
# INFO:root:Training on iteration 1200 of 10000
# INFO:root:single iteration took 1.040 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1210 of 10000
# INFO:root:single iteration took 1.034 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1220 of 10000
# INFO:root:single iteration took 1.033 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1230 of 10000
# INFO:root:single iteration took 1.034 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1240 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1250 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 12 percent complete
# INFO:root:Training on iteration 1260 of 10000
# INFO:root:single iteration took 0.990 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1270 of 10000
# INFO:root:single iteration took 0.998 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1280 of 10000
# INFO:root:single iteration took 1.072 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1290 of 10000
# INFO:root:single iteration took 1.072 seconds
# INFO:root:Training is 12 percent complete
#
# INFO:root:Training on iteration 1300 of 10000
# INFO:root:single iteration took 0.994 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1310 of 10000
# INFO:root:single iteration took 1.029 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1320 of 10000
# INFO:root:single iteration took 0.993 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1330 of 10000
# INFO:root:single iteration took 1.044 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1340 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1350 of 10000
# INFO:root:single iteration took 0.995 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1360 of 10000
# INFO:root:single iteration took 0.977 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1370 of 10000
# INFO:root:single iteration took 0.980 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1380 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1390 of 10000
# INFO:root:single iteration took 1.005 seconds
# INFO:root:Training is 13 percent complete
#
# INFO:root:Training on iteration 1400 of 10000
# INFO:root:single iteration took 1.045 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1410 of 10000
# INFO:root:single iteration took 1.031 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1420 of 10000
# INFO:root:single iteration took 1.043 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1430 of 10000
# INFO:root:single iteration took 1.030 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1440 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1450 of 10000
# INFO:root:single iteration took 1.034 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1460 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1470 of 10000
# INFO:root:single iteration took 1.030 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1480 of 10000
# INFO:root:single iteration took 1.024 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1490 of 10000
# INFO:root:single iteration took 1.007 seconds
# INFO:root:Training is 14 percent complete
#
# INFO:root:Training on iteration 1500 of 10000
# INFO:root:single iteration took 1.024 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Training on iteration 1510 of 10000
# INFO:root:single iteration took 0.989 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1520 of 10000
# INFO:root:single iteration took 0.983 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1530 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1540 of 10000
# INFO:root:single iteration took 1.019 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1550 of 10000
# INFO:root:single iteration took 1.071 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1560 of 10000
# INFO:root:single iteration took 1.068 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1570 of 10000
# INFO:root:single iteration took 1.005 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1580 of 10000
# INFO:root:single iteration took 1.037 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1590 of 10000
# INFO:root:single iteration took 1.023 seconds
# INFO:root:Training is 15 percent complete
#
# INFO:root:Training on iteration 1600 of 10000
# INFO:root:single iteration took 1.111 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1610 of 10000
# INFO:root:single iteration took 1.047 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1620 of 10000
# INFO:root:single iteration took 1.076 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1630 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1640 of 10000
# INFO:root:single iteration took 1.050 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1650 of 10000
# INFO:root:single iteration took 1.033 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1660 of 10000
# INFO:root:single iteration took 1.102 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1670 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1680 of 10000
# INFO:root:single iteration took 1.065 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1690 of 10000
# INFO:root:single iteration took 1.076 seconds
# INFO:root:Training is 16 percent complete
#
# INFO:root:Training on iteration 1700 of 10000
# INFO:root:single iteration took 1.030 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1710 of 10000
# INFO:root:single iteration took 1.056 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1720 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1730 of 10000
# INFO:root:single iteration took 1.117 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1740 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1750 of 10000
# INFO:root:single iteration took 1.037 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1760 of 10000
# INFO:root:single iteration took 1.047 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1770 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1780 of 10000
# INFO:root:single iteration took 1.036 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1790 of 10000
# INFO:root:single iteration took 1.068 seconds
# INFO:root:Training is 17 percent complete
#
# INFO:root:Training on iteration 1800 of 10000
# INFO:root:single iteration took 1.039 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1810 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1820 of 10000
# INFO:root:single iteration took 1.094 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1830 of 10000
# INFO:root:single iteration took 1.074 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1840 of 10000
# INFO:root:single iteration took 1.032 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1850 of 10000
# INFO:root:single iteration took 1.065 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1860 of 10000
# INFO:root:single iteration took 1.046 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1870 of 10000
# INFO:root:single iteration took 1.071 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1880 of 10000
# INFO:root:single iteration took 1.038 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1890 of 10000
# INFO:root:single iteration took 1.042 seconds
# INFO:root:Training is 18 percent complete
#
# INFO:root:Training on iteration 1900 of 10000
# INFO:root:single iteration took 1.035 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1910 of 10000
# INFO:root:single iteration took 1.032 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1920 of 10000
# INFO:root:single iteration took 1.100 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1930 of 10000
# INFO:root:single iteration took 1.024 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1940 of 10000
# INFO:root:single iteration took 1.008 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1950 of 10000
# INFO:root:single iteration took 1.008 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1960 of 10000
# INFO:root:single iteration took 1.029 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1970 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1980 of 10000
# INFO:root:single iteration took 1.008 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 1990 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 19 percent complete
#
# INFO:root:Training on iteration 2000 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2010 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2020 of 10000
# INFO:root:single iteration took 1.071 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2030 of 10000
# INFO:root:single iteration took 1.002 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2040 of 10000
# INFO:root:single iteration took 0.989 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2050 of 10000
# INFO:root:single iteration took 0.987 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2060 of 10000
# INFO:root:single iteration took 1.004 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2070 of 10000
# INFO:root:single iteration took 0.987 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2080 of 10000
# INFO:root:single iteration took 0.990 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2090 of 10000
# INFO:root:single iteration took 1.004 seconds
# INFO:root:Training is 20 percent complete
#
# INFO:root:Training on iteration 2100 of 10000
# INFO:root:single iteration took 1.007 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2110 of 10000
# INFO:root:single iteration took 0.971 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2120 of 10000
# INFO:root:single iteration took 1.002 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2130 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2140 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2150 of 10000
# INFO:root:single iteration took 0.996 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2160 of 10000
# INFO:root:single iteration took 1.001 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2170 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2180 of 10000
# INFO:root:single iteration took 0.996 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2190 of 10000
# INFO:root:single iteration took 1.006 seconds
# INFO:root:Training is 21 percent complete
#
# INFO:root:Training on iteration 2200 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2210 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2220 of 10000
# INFO:root:single iteration took 1.008 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2230 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2240 of 10000
# INFO:root:single iteration took 0.995 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2250 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2260 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2270 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2280 of 10000
# INFO:root:single iteration took 1.020 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2290 of 10000
# INFO:root:single iteration took 0.993 seconds
# INFO:root:Training is 22 percent complete
#
# INFO:root:Training on iteration 2300 of 10000
# INFO:root:single iteration took 0.990 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2310 of 10000
# INFO:root:single iteration took 0.983 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2320 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2330 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2340 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2350 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2360 of 10000
# INFO:root:single iteration took 1.020 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2370 of 10000
# INFO:root:single iteration took 0.984 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2380 of 10000
# INFO:root:single iteration took 1.024 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2390 of 10000
# INFO:root:single iteration took 1.008 seconds
# INFO:root:Training is 23 percent complete
#
# INFO:root:Training on iteration 2400 of 10000
# INFO:root:single iteration took 1.001 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2410 of 10000
# INFO:root:single iteration took 1.021 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2420 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2430 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2440 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2450 of 10000
# INFO:root:single iteration took 1.018 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2460 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2470 of 10000
# INFO:root:single iteration took 1.024 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2480 of 10000
# INFO:root:single iteration took 1.004 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2490 of 10000
# INFO:root:single iteration took 0.990 seconds
# INFO:root:Training is 24 percent complete
#
# INFO:root:Training on iteration 2500 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2510 of 10000
# INFO:root:single iteration took 0.986 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2520 of 10000
# INFO:root:single iteration took 1.030 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2530 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2540 of 10000
# INFO:root:single iteration took 0.993 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2550 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2560 of 10000
# INFO:root:single iteration took 1.021 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2570 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2580 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2590 of 10000
# INFO:root:single iteration took 1.026 seconds
# INFO:root:Training is 25 percent complete
#
# INFO:root:Training on iteration 2600 of 10000
# INFO:root:single iteration took 1.007 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2610 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2620 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2630 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2640 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2650 of 10000
# INFO:root:single iteration took 1.018 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2660 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2670 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2680 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2690 of 10000
# INFO:root:single iteration took 0.998 seconds
# INFO:root:Training is 26 percent complete
#
# INFO:root:Training on iteration 2700 of 10000
# INFO:root:single iteration took 0.998 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2710 of 10000
# INFO:root:single iteration took 0.985 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2720 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2730 of 10000
# INFO:root:single iteration took 1.018 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2740 of 10000
# INFO:root:single iteration took 0.985 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2750 of 10000
# INFO:root:single iteration took 0.996 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2760 of 10000
# INFO:root:single iteration took 0.984 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2770 of 10000
# INFO:root:single iteration took 0.981 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2780 of 10000
# INFO:root:single iteration took 1.002 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2790 of 10000
# INFO:root:single iteration took 1.001 seconds
# INFO:root:Training is 27 percent complete
#
# INFO:root:Training on iteration 2800 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2810 of 10000
# INFO:root:single iteration took 1.030 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2820 of 10000
# INFO:root:single iteration took 1.020 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2830 of 10000
# INFO:root:single iteration took 1.021 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2840 of 10000
# INFO:root:single iteration took 1.021 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2850 of 10000
# INFO:root:single iteration took 1.028 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2860 of 10000
# INFO:root:single iteration took 1.028 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2870 of 10000
# INFO:root:single iteration took 1.022 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2880 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2890 of 10000
# INFO:root:single iteration took 1.023 seconds
# INFO:root:Training is 28 percent complete
#
# INFO:root:Training on iteration 2900 of 10000
# INFO:root:single iteration took 1.031 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2910 of 10000
# INFO:root:single iteration took 1.019 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2920 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2930 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2940 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2950 of 10000
# INFO:root:single iteration took 1.021 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2960 of 10000
# INFO:root:single iteration took 1.004 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2970 of 10000
# INFO:root:single iteration took 1.004 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2980 of 10000
# INFO:root:single iteration took 1.020 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 2990 of 10000
# INFO:root:single iteration took 1.021 seconds
# INFO:root:Training is 29 percent complete
#
# INFO:root:Training on iteration 3000 of 10000
# INFO:root:single iteration took 0.993 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Training on iteration 3010 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3020 of 10000
# INFO:root:single iteration took 1.025 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3030 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3040 of 10000
# INFO:root:single iteration took 1.029 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3050 of 10000
# INFO:root:single iteration took 1.016 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3060 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3070 of 10000
# INFO:root:single iteration took 1.005 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3080 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3090 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 30 percent complete
#
# INFO:root:Training on iteration 3100 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3110 of 10000
# INFO:root:single iteration took 1.021 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3120 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3130 of 10000
# INFO:root:single iteration took 1.002 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3140 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3150 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3160 of 10000
# INFO:root:single iteration took 1.020 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3170 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3180 of 10000
# INFO:root:single iteration took 1.005 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3190 of 10000
# INFO:root:single iteration took 0.993 seconds
# INFO:root:Training is 31 percent complete
#
# INFO:root:Training on iteration 3200 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3210 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3220 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3230 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3240 of 10000
# INFO:root:single iteration took 1.020 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3250 of 10000
# INFO:root:single iteration took 1.006 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3260 of 10000
# INFO:root:single iteration took 1.007 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3270 of 10000
# INFO:root:single iteration took 1.008 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3280 of 10000
# INFO:root:single iteration took 0.989 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3290 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 32 percent complete
#
# INFO:root:Training on iteration 3300 of 10000
# INFO:root:single iteration took 0.999 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3310 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3320 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3330 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3340 of 10000
# INFO:root:single iteration took 1.005 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3350 of 10000
# INFO:root:single iteration took 1.002 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3360 of 10000
# INFO:root:single iteration took 1.004 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3370 of 10000
# INFO:root:single iteration took 0.988 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3380 of 10000
# INFO:root:single iteration took 1.002 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3390 of 10000
# INFO:root:single iteration took 0.985 seconds
# INFO:root:Training is 33 percent complete
#
# INFO:root:Training on iteration 3400 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3410 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3420 of 10000
# INFO:root:single iteration took 0.998 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3430 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3440 of 10000
# INFO:root:single iteration took 0.992 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3450 of 10000
# INFO:root:single iteration took 0.983 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3460 of 10000
# INFO:root:single iteration took 0.991 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3470 of 10000
# INFO:root:single iteration took 1.006 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3480 of 10000
# INFO:root:single iteration took 1.007 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3490 of 10000
# INFO:root:single iteration took 0.986 seconds
# INFO:root:Training is 34 percent complete
#
# INFO:root:Training on iteration 3500 of 10000
# INFO:root:single iteration took 0.987 seconds
# INFO:root:Training is 35 percent complete
#
# INFO:root:Training on iteration 3510 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 35 percent complete
#
# INFO:root:Training on iteration 3520 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 35 percent complete
#
# INFO:root:Training on iteration 3530 of 10000
# INFO:root:single iteration took 0.982 seconds
# INFO:root:Training is 35 percent complete
#
# INFO:root:Training on iteration 3540 of 10000
# ...
# INFO:root:Training is 88 percent complete
#
# INFO:root:Training on iteration 8860 of 10000
# INFO:root:single iteration took 1.034 seconds
# INFO:root:Training is 88 percent complete
#
# INFO:root:Training on iteration 8870 of 10000
# INFO:root:single iteration took 1.066 seconds
# INFO:root:Training is 88 percent complete
#
# INFO:root:Training on iteration 8880 of 10000
# INFO:root:single iteration took 1.050 seconds
# INFO:root:Training is 88 percent complete
#
# INFO:root:Training on iteration 8890 of 10000
# INFO:root:single iteration took 1.103 seconds
# INFO:root:Training is 88 percent complete
#
# INFO:root:Training on iteration 8900 of 10000
# INFO:root:single iteration took 1.033 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8910 of 10000
# INFO:root:single iteration took 1.033 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8920 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8930 of 10000
# INFO:root:single iteration took 1.043 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8940 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8950 of 10000
# INFO:root:single iteration took 0.987 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8960 of 10000
# INFO:root:single iteration took 1.049 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8970 of 10000
# INFO:root:single iteration took 1.113 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8980 of 10000
# INFO:root:single iteration took 1.087 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 8990 of 10000
# INFO:root:single iteration took 1.064 seconds
# INFO:root:Training is 89 percent complete
#
# INFO:root:Training on iteration 9000 of 10000
# INFO:root:single iteration took 1.028 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Loading knots info for scene shirt_canonical
# INFO:root:Training on iteration 9010 of 10000
# INFO:root:single iteration took 1.091 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Training on iteration 9020 of 10000
# INFO:root:single iteration took 1.091 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Training on iteration 9030 of 10000
# INFO:root:single iteration took 1.151 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Training on iteration 9040 of 10000
# INFO:root:single iteration took 1.078 seconds
# INFO:root:Training is 90 percent complete
# INFO:root:Training on iteration 9050 of 10000
# INFO:root:single iteration took 1.073 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Training on iteration 9060 of 10000
# INFO:root:single iteration took 1.093 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Training on iteration 9070 of 10000
# INFO:root:single iteration took 1.089 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Training on iteration 9080 of 10000
# INFO:root:single iteration took 1.029 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Training on iteration 9090 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 90 percent complete
#
# INFO:root:Training on iteration 9100 of 10000
# INFO:root:single iteration took 1.026 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9110 of 10000
# INFO:root:single iteration took 1.012 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9120 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9130 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9140 of 10000
# INFO:root:single iteration took 1.025 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9150 of 10000
# INFO:root:single iteration took 1.030 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9160 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9170 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9180 of 10000
# INFO:root:single iteration took 1.018 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9190 of 10000
# INFO:root:single iteration took 1.030 seconds
# INFO:root:Training is 91 percent complete
#
# INFO:root:Training on iteration 9200 of 10000
# INFO:root:single iteration took 1.017 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9210 of 10000
# INFO:root:single iteration took 1.034 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9220 of 10000
# INFO:root:single iteration took 1.006 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9230 of 10000
# INFO:root:single iteration took 1.032 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9240 of 10000
# INFO:root:single iteration took 1.007 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9250 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9260 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9270 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9280 of 10000
# INFO:root:single iteration took 1.009 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9290 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 92 percent complete
#
# INFO:root:Training on iteration 9300 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9310 of 10000
# INFO:root:single iteration took 0.978 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9320 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9330 of 10000
# INFO:root:single iteration took 0.995 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9340 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9350 of 10000
# INFO:root:single iteration took 1.045 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9360 of 10000
# INFO:root:single iteration took 1.037 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9370 of 10000
# INFO:root:single iteration took 1.030 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9380 of 10000
# INFO:root:single iteration took 1.035 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9390 of 10000
# INFO:root:single iteration took 1.026 seconds
# INFO:root:Training is 93 percent complete
#
# INFO:root:Training on iteration 9400 of 10000
# INFO:root:single iteration took 1.035 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9410 of 10000
# INFO:root:single iteration took 1.028 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9420 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9430 of 10000
# INFO:root:single iteration took 1.028 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9440 of 10000
# INFO:root:single iteration took 1.027 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9450 of 10000
# INFO:root:single iteration took 1.034 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9460 of 10000
# INFO:root:single iteration took 1.029 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9470 of 10000
# INFO:root:single iteration took 1.031 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9480 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9490 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 94 percent complete
#
# INFO:root:Training on iteration 9500 of 10000
# INFO:root:single iteration took 1.033 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9510 of 10000
# INFO:root:single iteration took 1.013 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9520 of 10000
# INFO:root:single iteration took 1.028 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9530 of 10000
# INFO:root:single iteration took 1.026 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9540 of 10000
# INFO:root:single iteration took 1.031 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9550 of 10000
# INFO:root:single iteration took 1.014 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9560 of 10000
# INFO:root:single iteration took 1.002 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9570 of 10000
# INFO:root:single iteration took 1.000 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9580 of 10000
# INFO:root:single iteration took 1.015 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9590 of 10000
# INFO:root:single iteration took 1.026 seconds
# INFO:root:Training is 95 percent complete
#
# INFO:root:Training on iteration 9600 of 10000
# INFO:root:single iteration took 1.032 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9610 of 10000
# INFO:root:single iteration took 0.986 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9620 of 10000
# INFO:root:single iteration took 0.982 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9630 of 10000
# INFO:root:single iteration took 1.004 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9640 of 10000
# INFO:root:single iteration took 0.990 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9650 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 96 percent complete
# INFO:root:Training on iteration 9660 of 10000
# INFO:root:single iteration took 0.996 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9670 of 10000
# INFO:root:single iteration took 0.991 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9680 of 10000
# INFO:root:single iteration took 0.984 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9690 of 10000
# INFO:root:single iteration took 0.985 seconds
# INFO:root:Training is 96 percent complete
#
# INFO:root:Training on iteration 9700 of 10000
# INFO:root:single iteration took 0.986 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9710 of 10000
# INFO:root:single iteration took 0.983 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9720 of 10000
# INFO:root:single iteration took 0.991 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9730 of 10000
# INFO:root:single iteration took 0.986 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9740 of 10000
# INFO:root:single iteration took 0.986 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9750 of 10000
# INFO:root:single iteration took 0.988 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9760 of 10000
# INFO:root:single iteration took 0.987 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9770 of 10000
# INFO:root:single iteration took 0.971 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9780 of 10000
# INFO:root:single iteration took 0.987 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9790 of 10000
# INFO:root:single iteration took 0.984 seconds
# INFO:root:Training is 97 percent complete
#
# INFO:root:Training on iteration 9800 of 10000
# INFO:root:single iteration took 0.983 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9810 of 10000
# INFO:root:single iteration took 0.980 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9820 of 10000
# INFO:root:single iteration took 1.006 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9830 of 10000
# INFO:root:single iteration took 1.028 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9840 of 10000
# INFO:root:single iteration took 0.977 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9850 of 10000
# INFO:root:single iteration took 0.975 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9860 of 10000
# INFO:root:single iteration took 0.983 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9870 of 10000
# INFO:root:single iteration took 0.979 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9880 of 10000
# INFO:root:single iteration took 0.996 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9890 of 10000
# INFO:root:single iteration took 0.986 seconds
# INFO:root:Training is 98 percent complete
#
# INFO:root:Training on iteration 9900 of 10000
# INFO:root:single iteration took 0.991 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9910 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9920 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9930 of 10000
# INFO:root:single iteration took 1.010 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9940 of 10000
# INFO:root:single iteration took 0.997 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9950 of 10000
# INFO:root:single iteration took 0.978 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9960 of 10000
# INFO:root:single iteration took 0.994 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9970 of 10000
# INFO:root:single iteration took 1.003 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9980 of 10000
# INFO:root:single iteration took 0.979 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 9990 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 99 percent complete
#
# INFO:root:Training on iteration 10000 of 10000
# INFO:root:single iteration took 1.011 seconds
# INFO:root:Training is 100 percent complete
#
# INFO:root:Finished testing after 10000 iterations
# finished training descriptor of dimension 16
# training took 13876 seconds

# %%
# t = torch.cuda.get_device_properties(0).total_memory
# r = torch.cuda.memory_reserved(0)
# a = torch.cuda.memory_allocated(0)
# f = r-a  # free inside reserved
# print('Current cuda device ID:', torch.cuda.current_device())
# print('Total memory available:', t/1e9, 'GB')
# print('Reserved memory:       ', r/1e9, 'GB')
# print('Allocated memory:      ', a/1e9, 'GB')
# print('Memory to use:         ', f/1e9, 'GB')

# %%
import matplotlib.pyplot as plt

config_filename = os.path.join(logging_dir, name, utils.getPaddedString(num_iterations, width=6) + '_log_history.yaml')
config = utils.getDictFromYamlFilename(config_filename)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15,5))
ax.plot(config['train']['total_loss'])
ax.set_title('Total_loss ' + name)
# ax.set_ylim([100,700])

plt.tight_layout()

# %% [markdown]
# ## EVAL

# %%
if EVALUATE:
    model_folder = os.path.join(logging_dir, name)
    model_folder = utils.convert_to_absolute_path(model_folder)
    DCE = DenseCorrespondenceEvaluation
    num_image_pairs = 100
    DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs)
# Out:
# got /home/gridsan/aportillo/pytorch-dense-correspondence/pdc/trained_models/tutorials/shirt_hanging_d16_distributional_sym_big
# output_dir:  /home/gridsan/aportillo/pytorch-dense-correspondence/pdc/trained_models/tutorials/shirt_hanging_d16_distributional_sym_big/analysis
# train_output_dir:  /home/gridsan/aportillo/pytorch-dense-correspondence/pdc/trained_models/tutorials/shirt_hanging_d16_distributional_sym_big/analysis/train
# test_output_dir:  /home/gridsan/aportillo/pytorch-dense-correspondence/pdc/trained_models/tutorials/shirt_hanging_d16_distributional_sym_big/analysis/test
# cross_scene_output_dir: /home/gridsan/aportillo/pytorch-dense-correspondence/pdc/trained_models/tutorials/shirt_hanging_d16_distributional_sym_big/analysis/cross_scene
#
# creating necessary dirs
# model_param_file 010001.pth
# INFO:root:Computing descriptor statistics on dataset
# INFO:root:Loading knots info for scene shirt_hanging
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     1500
# computing stats
# doing dcn eval
# INFO:root:Evaluating network on train data
# INFO:root:Loading knots info for scene shirt_canonical
# done computing stats
# computing statistics for image 0 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 5 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 10 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 15 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 20 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 25 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 30 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 35 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 40 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 45 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 50 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 55 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 60 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 65 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 70 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 75 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 80 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 85 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 90 of 100, scene_name shirt_hanging
# scene
# computing statistics for image 95 of 100, scene_name shirt_hanging
# scene
# INFO:root:Evaluating network on test data
# INFO:root:Loading knots info for scene shirt_hanging_test
# computing statistics for image 0 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 5 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 10 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 15 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 20 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 25 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 30 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 35 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 40 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 45 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 50 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 55 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 60 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 65 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 70 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 75 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 80 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 85 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 90 of 100, scene_name shirt_hanging_test
# scene
# computing statistics for image 95 of 100, scene_name shirt_hanging_test
# scene
# INFO:root:Making plots
# INFO:root:Finished running evaluation on network
